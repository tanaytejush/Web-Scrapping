# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url = 'https://ge.iitm.ac.in/mou/foreign-universities'

# %%
page = requests.get(url)

# %%
soup = BeautifulSoup(page.text, 'html')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# ...
